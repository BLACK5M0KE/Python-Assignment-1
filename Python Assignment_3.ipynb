# %%
# 1. Why are functions advantageous to have in your programs?
# Functions help in reusability, modularity, and easier debugging.


# 2. When does the code in a function run: when it's specified or when it's called?
# The code inside a function runs only when the function is called.

def example_function():
    print("Function executed")

example_function()  # Calls the function


# 3. What statement creates a function?
# The 'def' statement is used to create a function.
def my_function():
    pass  # Placeholder for function body


# 4. What is the difference between a function and a function call?
# A function is the defined block of code, while a function call executes that code.
def greet():
    print("Hello!")

greet()  # This is a function call


# 5. How many global scopes are there in a Python program? How many local scopes?
# There is only one global scope, but multiple local scopes can exist within functions.


# 6. What happens to variables in a local scope when the function call returns?
# They are destroyed once the function completes execution.
def example():
    local_var = 10  # This variable exists only inside this function


# 7. What is the concept of a return value? Is it possible to have a return value in an expression?
# A return value is the output of a function. Yes, it can be used in an expression.
def square(n):
    return n * n

result = square(5) + 10  # Using the return value in an expression


# 8. If a function does not have a return statement, what is the return value of a call to that function?
# It returns 'None' by default.
def no_return():
    pass

print(no_return())  # Output: None


# 9. How do you make a function variable refer to the global variable?
# Use the 'global' keyword.
global_var = 5

def modify_global():
    global global_var
    global_var = 10  # Modifies the global variable


# 10. What is the data type of None?
# The type of None is 'NoneType'.
print(type(None))  # Output: <class 'NoneType'>


# 11. What does the sentence 'import areallyourpetsnamederic' do?
# It tries to import a module named 'areallyourpetsnamederic', which likely doesn't exist.


# 12. If you had a bacon() function in a spam module, how would you call it after importing spam?
import spam
spam.bacon()  # Calls the function


# 13. What can you do to save a program from crashing if it encounters an error?
# Use exception handling with try-except blocks.
try:
    x = 1 / 0  # Causes an error
except ZeroDivisionError:
    print("Cannot divide by zero")


# 14. What is the purpose of the try clause? What is the purpose of the except clause?
# The try clause contains the code that might cause an error.
# The except clause handles the error if it occurs.
